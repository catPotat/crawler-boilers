# %% [markdown]
# ## KMeans Clustering
#
# Use the dataset in link:
# https://www.kaggle.com/datasets/yasserh/customer-segmentation-dataset

# %% [markdown]
# 1. Load the dataset -- 0.5 marks
# 2. Clean the dataset -- 0.5 marks
# 3. EDA -- 2 marks
# 4. Split the dataset  -- 0.5 marks
# 5. Encode and Standardization -- 0.5 marks
# 6. Select the correct number of ks  -- 2 marks
# 7. Modelling -- 2 marks
# 8. Result visualization -- 2 marks

# %% [markdown]
# ## 1. Import Data

# %% [markdown]
# ## 2. Cleaning
#
# Let's see whether missing values.
#
# Before anything, let's drop the customer ID column.

# %%
#your code

# %% [markdown]
# ### Check missing value

# %%
#your code

# %% [markdown]
# ### Check whether any incorrect data entry

# %%
#your code

# %% [markdown]
# ### Label encoding
#
# Because Gender has only two possible values, we can safely use label encoding turning Gender to 0 and 1.

# %%
#your code

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %% [markdown]
# Let's do a pair plot to quickly gain some intuition of the dataset

# %%
#your code

# %% [markdown]
# Explain what you observe

# %% [markdown]
# ## 4. Modeling using K-Means

# %% [markdown]
# ### Finding the optimal k of K-Means using Elbow method. Show the plot and justify your result.

# %%
#your code

# %% [markdown]
# ### K-Means

# %% [markdown]
# How many clusters do you use? Justify your results.

# %%
#your code to implement K-Means clustering

# %% [markdown]
# ### Visualize results

# %%
#your code
